# %%
from tqdm.notebook import tqdm
import pandas as pd
import pickle
import numpy as np
import sys
sys.path.insert(1, './helpers')
import web_table
import json
import os
import time

# %%
with open('./source/sub_domz_df.pickle', 'rb') as handle:
    dmoz_df = pickle.load(handle)

# %% [markdown]
# # filter
#
# - Minimum of 2 rows
#
# - Minimum of 2 columns
#
# - No cell with more than 100 characters in it.

# %%
def filter_longer(flatten_array):
    for value in flatten_array:
        if isinstance(value, str) and len(value) > 100:
            return True
    return False
def is_pass_filter(df):
    temp_df = df.dropna()
    if temp_df.shape[0] < 2:
        return False
    
    if temp_df.shape[1] < 2:
        return False
    
    if filter_longer(df.values.flatten()):
        return False
    
    return True

# %%
labels = ['Home', 'Society', 'Business', 'Arts', 'Recreation', 'Health',
 'News', 'Computers', 'Sports', 'Games', 'Reference', 'Science', 'Shopping']

label_dict = {}
for label in labels:
    label_dict[label] = {
        'true': 0,
        'false': 0
    }

# dmoz_df = dmoz_df[200: 300]

# %%
# from interruptingcow import timeout
# try:
#     with timeout(5, exception=RuntimeError):
#         while True:
#             test = 0
#             if test == 5:
#                 break
#             test = test - 1
# except RuntimeError:
#     print (RuntimeError)

# %%
web_table_list_count = []
extension_list = []
data_list = []
with tqdm(total=1000) as pbar:
    for index, row in dmoz_df[:1000].iterrows():

        df_list, e = web_table.extractor(row['domain'])

        if e != '':
            extension_list.append(e)
            print (e)

        for df in df_list:
            if is_pass_filter(df):
                label_dict[row['label']]['true'] += 1
                data_list.append([row['domain'], row['label'], df])
            else:
                label_dict[row['label']]['false'] += 1

        pbar.update(1)
        

#print(data_list)
#data = []
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# No tables found
# No tables found
# No tables found
# HTTP Error 404: Not Found
# No tables found
# No tables found
# HTTP Error 403: Bad Behavior
# No tables found
# HTTP Error 406: Not Acceptable
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 54] Connection reset by peer>
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
#
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found matching pattern '.+'
# No tables found
# HTTP Error 502: Bad Gateway
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# HTTP Error 404: Not Found
#
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# b'failed to load external entity ""' (line 0)
# No tables found
# No tables found
# No tables found
#
# No tables found
#
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 404: Not Found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
#
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# HTTP Error 500: Internal Server Error
# b'failed to load external entity ""' (line 0)
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)>
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# HTTP Error 404: Not Found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# HTTP Error 500: Internal Server Error
# No tables found
# No tables found
# HTTP Error 404: Not Found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 308: Permanent Redirect
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# HTTP Error 500: Internal Server Error
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
#
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# [Errno 54] Connection reset by peer
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found matching pattern '.+'
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
#
# No tables found
# No tables found
# HTTP Error 404: Site Not Found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
#
# No tables found
# No tables found
# HTTP Error 403: Forbidden
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
#
#
# No tables found
# No tables found
# HTTP Error 308: Permanent Redirect
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 404: Not Found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# b'failed to load external entity ""' (line 0)
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 403: Forbidden
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 403: Forbidden
#
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# HTTP Error 403: Forbidden
#
# No tables found
# No tables found
#
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# <urlopen error [Errno 54] Connection reset by peer>
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 404: Not Found
# No tables found
# No tables found
# HTTP Error 503: Service Unavailable
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# b'failed to load external entity ""' (line 0)
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 302: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# HTTP Error 404: Not Found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 403: Forbidden
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
#
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# HTTP Error 308: Unknown Code
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
#
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
#
# No tables found
# HTTP Error 403: User Agent Denied
# No tables found
# No tables found
# No tables found
# HTTP Error 404: Not Found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
#
# No tables found matching pattern '.+'
# HTTP Error 404: Not Found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)>
# No tables found
# HTTP Error 404: Not Found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 61] Connection refused>
# No tables found
#
# HTTP Error 403: Forbidden
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
#
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# <urlopen error [Errno 65] No route to host>
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# HTTP Error 400: Bad Request
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
#
# HTTP Error 403: Forbidden
# HTTP Error 500: Internal Server Error
# No tables found
# HTTP Error 503: Service Temporarily Unavailable
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 61] Connection refused>
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
#
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# <urlopen error [Errno 8] nodename nor servname provided, or not known>
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found
# No tables found

# %%
# with open('data/data.pickle', 'rb') as fp:
#     data = pickle.load(fp)
#     print(len(data))
# print(len(data_list))
# with open('data/data.pickle', 'wb') as fp:
#     data.extend(data_list)
#     print(len(data))
#     pickle.dump(data, fp)

# %%
extension_list
# Out:
# [ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 403: 'Bad Behavior'>,
#  ValueError('No tables found'),
#  <HTTPError 406: 'Not Acceptable'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(ConnectionResetError(54, 'Connection reset by peer')),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError("No tables found matching pattern '.+'"),
#  ValueError('No tables found'),
#  <HTTPError 502: 'Bad Gateway'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  RuntimeError(),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  lxml.etree.XMLSyntaxError(b'failed to load external entity ""'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 500: 'Internal Server Error'>,
#  lxml.etree.XMLSyntaxError(b'failed to load external entity ""'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(ssl.SSLCertVerificationError(1,
#                                                     '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)')),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  <HTTPError 500: 'Internal Server Error'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 308: 'Permanent Redirect'>,
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  <HTTPError 500: 'Internal Server Error'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  RuntimeError(),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ConnectionResetError(54, 'Connection reset by peer'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError("No tables found matching pattern '.+'"),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Site Not Found'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 403: 'Forbidden'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 308: 'Permanent Redirect'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  lxml.etree.XMLSyntaxError(b'failed to load external entity ""'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  <HTTPError 404: 'Not Found'>,
#  <HTTPError 403: 'Forbidden'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 403: 'Forbidden'>,
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  <HTTPError 403: 'Forbidden'>,
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  urllib.error.URLError(ConnectionResetError(54, 'Connection reset by peer')),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 503: 'Service Unavailable'>,
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  lxml.etree.XMLSyntaxError(b'failed to load external entity ""'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 302: 'The HTTP server returned a redirect error that would lead to an infinite loop.\nThe last 30x error message was:\nFound'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  <HTTPError 404: 'Not Found'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 403: 'Forbidden'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 301: 'The HTTP server returned a redirect error that would lead to an infinite loop.\nThe last 30x error message was:\nMoved Permanently'>,
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  <HTTPError 308: 'Unknown Code'>,
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  <HTTPError 404: 'Not Found'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  <HTTPError 403: 'User Agent Denied'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError("No tables found matching pattern '.+'"),
#  <HTTPError 404: 'Not Found'>,
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  urllib.error.URLError(ssl.SSLCertVerificationError(1,
#                                                     '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)')),
#  ValueError('No tables found'),
#  <HTTPError 404: 'Not Found'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(ConnectionRefusedError(61, 'Connection refused')),
#  ValueError('No tables found'),
#  RuntimeError(),
#  <HTTPError 403: 'Forbidden'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  RuntimeError(),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  urllib.error.URLError(OSError(65, 'No route to host')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  <HTTPError 400: 'Bad Request'>,
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  <HTTPError 403: 'Forbidden'>,
#  <HTTPError 500: 'Internal Server Error'>,
#  ValueError('No tables found'),
#  <HTTPError 503: 'Service Temporarily Unavailable'>,
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(ConnectionRefusedError(61, 'Connection refused')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  RuntimeError(),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  urllib.error.URLError(socket.gaierror(8,
#                                        'nodename nor servname provided, or not known')),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found'),
#  ValueError('No tables found')]

# %%
label_dict
# Out:
# {'Home': {'true': 0, 'false': 8},
#  'Society': {'true': 8, 'false': 101},
#  'Business': {'true': 44, 'false': 581},
#  'Arts': {'true': 6, 'false': 198},
#  'Recreation': {'true': 8, 'false': 119},
#  'Health': {'true': 66, 'false': 83},
#  'News': {'true': 0, 'false': 22},
#  'Computers': {'true': 9, 'false': 93},
#  'Sports': {'true': 14, 'false': 27},
#  'Games': {'true': 0, 'false': 38},
#  'Reference': {'true': 1, 'false': 34},
#  'Science': {'true': 0, 'false': 33},
#  'Shopping': {'true': 0, 'false': 60}}
